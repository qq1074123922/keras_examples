# %%
import pickle
import sys

# %%
f2 = open('vocab.pkl', 'rb') 
vocab=pickle.load(f2,encoding='utf-8')
#vocab是一个字典，统计好了，每一个单词出现的次数，

# %%
vocab['atp-cache']
# Out:
# 5

# %%
f1=open('W.pkl','rb')
W=pickle.load(f1,encoding='bytes')

# %%
f3=open('W2.pkl','rb')
W2=pickle.load(f3,encoding='bytes')

# %%
len(W[0])
# Out:
# 144953

# %%
len(W[1])
# Out:
# 144952

# %%
len(W2[0])
# Out:
# 5544

# %%
len(W2[1])
# Out:
# 144952

# %%
W[0][1]
# Out:
# array([ -3.51529986e-01,   7.97030032e-02,   1.62630007e-01,
#          6.84589982e-01,   4.88539994e-01,   4.82089996e-01,
#          2.68169999e-01,  -2.01570004e-01,  -5.23679972e-01,
#         -1.83449996e+00,  -3.05240005e-01,   2.76959985e-01,
#         -8.12709987e-01,   1.54280007e-01,  -6.56099975e-01,
#          6.06339991e-01,   6.29170001e-01,  -6.21840000e-01,
#          2.60320008e-01,  -8.05850029e-01,   3.80519986e-01,
#         -2.68859994e-02,   2.01660007e-01,  -1.80020005e-01,
#          1.52740002e-01,  -5.17750025e-01,  -8.03570002e-02,
#          4.12919998e-01,  -1.08659998e-01,  -3.55419993e-01,
#          3.54579985e-01,   2.31260005e-02,   3.30559999e-01,
#          2.71640003e-01,  -4.61270005e-01,  -1.15730003e-01,
#          8.71900022e-02,  -3.06470007e-01,   3.73019993e-01,
#          3.17589998e-01,   2.15680003e-02,   4.69049990e-01,
#          3.47319990e-01,  -3.31589997e-01,   6.86930001e-01,
# ...
